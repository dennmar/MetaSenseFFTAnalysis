# %% [markdown]
# # Shafter Round 3 Board 19

# %%
from interactive_fft_grapher import graph_fft, get_fig_num
RAW_DATA_DIR = '/mnt/d/Internships/RawDataCSVs/'
# %matplotlib notebook

# %%
graph_fft(RAW_DATA_DIR, 'Shafter', 3, 19, 'No2WmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graph_fft(RAW_DATA_DIR, 'Shafter', 3, 19, 'No2AmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graph_fft(RAW_DATA_DIR, 'Shafter', 3, 19, 'OxWmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graph_fft(RAW_DATA_DIR, 'Shafter', 3, 19, 'OxAmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graph_fft(RAW_DATA_DIR, 'Shafter', 3, 19, 'CoWmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graph_fft(RAW_DATA_DIR, 'Shafter', 3, 19, 'CoAmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">
