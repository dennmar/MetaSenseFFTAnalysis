# %% [markdown]
# # El Cajon Round 2 Board 17

# %%
from interactive_fft_grapher import graph_fft, get_fig_num
RAW_DATA_DIR = '/mnt/d/Internships/RawDataCSVs/'
# %matplotlib notebook

# %%
graph_fft(RAW_DATA_DIR, 'El_Cajon', 2, 17, 'No2WmV', None, get_fig_num())

# %%
graph_fft(RAW_DATA_DIR, 'El_Cajon', 2, 17, 'No2AmV', None, get_fig_num())

# %%
graph_fft(RAW_DATA_DIR, 'El_Cajon', 2, 17, 'OxWmV', None, get_fig_num())

# %%
graph_fft(RAW_DATA_DIR, 'El_Cajon', 2, 17, 'OxAmV', None, get_fig_num())

# %%
graph_fft(RAW_DATA_DIR, 'El_Cajon', 2, 17, 'CoWmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graph_fft(RAW_DATA_DIR, 'El_Cajon', 2, 17, 'CoAmV', None, get_fig_num())
# Out:
# <img src="data:image/png;base64,..." width="640">
